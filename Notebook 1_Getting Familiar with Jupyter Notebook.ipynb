# %% [markdown]
# # Module 1: Python Fundamentals
# ## Course: DSC101_Introduction to Data Science
# ### Notebook 1: Getting Familiar with Jupyter Notebook

# %% [markdown]
# ## **Basic Editing in Jupyter Notebook**

# %% [markdown]
# 1. **Add a New Cell:**
#
# Click on the  + and select either 'Code' or 'Markdown' from the dropdown option.
#
# You can use upward or downward arrow to move the cell.

# %% [markdown]
# 2. **Running Cells**
#
# Click the play button on the menu bar, or use **Shift + Enter** to run the cell. It automatically move to the next one.

# %% [markdown]
# 3. **Editing Text Cells with Markdown**
#
# Use Markdown syntax to create headings, lists, links, images, and formatted text.
#
# - Headings: Use #, ##, ### for different levels.
# - Bold: **bold text**
# - Italic: *italic text*
# - Bullet List: - item 1
# - Numbered List: 1. item 1
# - Embed LaTeX for mathematical equations:
# Example: $y = mx + c$

# %% [markdown]
# ![image.png](attachment:96b04d71-4b65-4c08-aa1e-6bfaa0092fd0.png)

# %% [markdown]
# https://jupyter.org/

# %% [markdown]
# 4. **Code Formatting and Indentation**
#
# - Python code in the Jupyter Notebook follows the standard indentation rules. Use four spaces for **indentation**, or press Tab once.

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
# highlights syntax errors
print(dsc101)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 # highlights syntax errors
# ----> 2 print(dsc101)
#
# NameError: name 'dsc101' is not defined

# %% [markdown]
# 5. **Comments in Code**
#
# - Use triple quotes """ or ''' for multi-line comments in code chunk.
# Commenting your code improves readability and helps others understand your work.

# %%
'''
Hi, I am a Data Scientist.
I am interested on applications on HealthCare.
'''
first_name = 'Binod'
last_name = 'Rimal'
name = first_name +' '+ last_name
print(name)
# Out:
# Binod Rimal

# %% [markdown]
# - Use # for single-line comments in code chunk

# %%
'''
Print multiple lines.
\n is for new line.
'''

print('Lets Learn Python Basics! \n Python is incredible!!')

# printing a blank line
print("\n")

print('We will use python tools for data analysis.')
# Out:
# Lets Learn Python Basics!
#  Python is incredible!!
#
#
# We will use python tools for data analysis.

# %% [markdown]
# ## **Your turn**
#
# Write (print) three-five new lines about your friend sitting next to you.

# %% [markdown]
# ## **Saving notebook as PDF**

# %% [markdown]
# - File >> Save and Export Notebook As >> HTML
# - Go to HTML:  Right Click >> Print >> Save as PDF
